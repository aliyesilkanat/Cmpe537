# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread("Images/img1.png")

# %%
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (640, 800)

# %%
descs.shape
# Out:
# (2678, 128)

# %%
sift = cv2.xfeatures2d.SIFT_create()
kp,descs = sift.detectAndCompute(gray,None)
a=cv2.drawKeypoints(img,kp,None,cv2.DRA)
plt.figure(figsize=(30,30))
plt.imshow(a)
plt.show()

# %%
a
# Out:
# array([[[215, 209, 219],
#         [215, 206, 216],
#         [207, 196, 206],
#         ...,
#         [ 27,  29,  20],
#         [ 28,  29,  31],
#         [ 18,  17,  30]],
#
#        [[211, 206, 217],
#         [217, 210, 221],
#         [219, 209, 220],
#         ...,
#         [ 42,  33,  29],
#         [ 35,  24,  28],
#         [ 32,  17,  32]],
#
#        [[213, 210, 222],
#         [215, 209, 222],
#         [215, 206, 219],
#         ...,
#         [ 39,  29,  30],
#         [ 39,  27,  32],
#         [ 35,  22,  35]],
#
#        ...,
#
#        [[ 29,  23, 178],
#         [ 22,  20, 174],
#         [ 22,  25, 176],
#         ...,
#         [ 47,  37,  39],
#         [ 46,  36,  37],
#         [ 51,  40,  40]],
#
#        [[ 17,  23, 178],
#         [ 24,  29, 186],
#         [ 28,  32, 189],
#         ...,
#         [ 47,  41,  41],
#         [ 47,  39,  41],
#         [ 47,  40,  41]],
#
#        [[ 23,  33, 185],
#         [ 26,  31, 186],
#         [ 30,  29, 188],
#         ...,
#         [ 43,  44,  42],
#         [ 40,  43,  43],
#         [ 35,  37,  41]]], dtype=uint8)

# %%
block_size = 2
aperture = 3
free_parameter = 0.04
dst = cv2.cornerHarris(gray, block_size, aperture, free_parameter)
#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
plt.imshow(img)
plt.show()

# %%
#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]
ma
# Out:
# (640, 800)

# %%
descs.shape
# Out:
# (2678, 128)

# %%
a
# Out:
# array([[[215, 209, 219],
#         [215, 206, 216],
#         [207, 196, 206],
#         ...,
#         [ 27,  29,  20],
#         [ 28,  29,  31],
#         [ 18,  17,  30]],
#
#        [[211, 206, 217],
#         [217, 210, 221],
#         [219, 209, 220],
#         ...,
#         [ 42,  33,  29],
#         [ 35,  24,  28],
#         [ 32,  17,  32]],
#
#        [[213, 210, 222],
#         [215, 209, 222],
#         [215, 206, 219],
#         ...,
#         [ 39,  29,  30],
#         [ 39,  27,  32],
#         [ 35,  22,  35]],
#
#        ...,
#
#        [[ 29,  23, 178],
#         [ 22,  20, 174],
#         [ 22,  25, 176],
#         ...,
#         [ 47,  37,  39],
#         [ 46,  36,  37],
#         [ 51,  40,  40]],
#
#        [[ 17,  23, 178],
#         [ 24,  29, 186],
#         [ 28,  32, 189],
#         ...,
#         [ 47,  41,  41],
#         [ 47,  39,  41],
#         [ 47,  40,  41]],
#
#        [[ 23,  33, 185],
#         [ 26,  31, 186],
#         [ 30,  29, 188],
#         ...,
#         [ 43,  44,  42],
#         [ 40,  43,  43],
#         [ 35,  37,  41]]], dtype=uint8)

# %%
kp
# Out:
# array([[  2., 127., 164., ...,  67.,   6.,   0.],
#        [  0.,   1., 111., ...,  20.,   6.,   0.],
#        [  0.,   0.,   0., ...,   0.,   0.,   1.],
#        ...,
#        [  0.,   1.,   8., ...,   0.,   0.,   0.],
#        [  2., 105.,  30., ...,   3.,   0.,   0.],
#        [  1.,   0.,   0., ...,   0.,   0.,   2.]], dtype=float32)
